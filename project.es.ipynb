# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd
import numpy as np

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')

ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
#        phone_realEstate                                       url_inmueble  \
# 0           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 1           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 2           916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 4           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# ...                 ...                                                ...
# 15330       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15331       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15332       912780348.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15333       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15334       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#        rooms  bathrooms  surface   price  ... level4Id level5Id level6Id  \
# 0        3.0        2.0    103.0  195000  ...        0        0        0
# 1        3.0        1.0      NaN   89000  ...        0        0        0
# 2        2.0        2.0     99.0  390000  ...        0        0        0
# 3        3.0        1.0     86.0   89000  ...        0        0        0
# 4        2.0        2.0    106.0  172000  ...        0        0        0
# ...      ...        ...      ...     ...  ...      ...      ...      ...
# 15330    2.0        1.0     96.0  259470  ...        0        0        0
# 15331    3.0        1.0    150.0  165000  ...        0        0        0
# 15332    4.0        2.0    175.0  495000  ...        0        0        0
# 15333    3.0        2.0    101.0  195000  ...        0        0        0
# 15334    3.0        2.0    152.0  765000  ...        0        0        0
#
#       level7Id level8Id accuracy          latitude          longitude zipCode  \
# 0            0        0        0  40,2948276786438  -3,44402412135624     NaN
# 1            0        0        1          40,28674           -3,79351     NaN
# 2            0        0        0  40,4115646786438  -3,90662252135624     NaN
# 3            0        0        0  40,2853785786438  -3,79508142135624     NaN
# 4            0        0        0  40,2998774864376  -3,45226301356237     NaN
# ...        ...      ...      ...               ...                ...     ...
# 15330        0        0        0          40,45416           -3,70286     NaN
# 15331        0        0        0          40,36652           -3,48951     NaN
# 15332        0        0        0          40,57444           -3,92124     NaN
# 15333        0        0        0          40,36967           -3,48105     NaN
# 15334        0        0        0          40,45773           -3,69068     NaN
#
#       customZone
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 15330        NaN
# 15331        NaN
# 15332        NaN
# 15333        NaN
# 15334        NaN
#
# [15335 rows x 37 columns]

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# TODO
# obtenemos el VALOR(precio) máximo de la columna 'price' mediante la function .max() que nos devuelve el valor máximo de la columna/ columnas
# si no especificamos nada.
xpensive_house = ds['price'].max()

# obtenemos la POSICIÓN del valor máximo de la columna 'price'.
position_xpensive_house = ds['price'].argmax()

# Accedemos al elemento específico (la dirección de la casa), utilizando la function .loc[row,column] (By Index), en la columna 'address' 
# ya sabiendo la posición(row) del paso anterior.
address_xpensive_house = ds.loc[position_xpensive_house, 'address']

# mediante f-string imprimimos los valores obtenidos.
print(f"La casa con dirección en {address_xpensive_house} es la más cara y su precio es de {xpensive_house} EUR.")
# Out:
# La casa con dirección en El Escorial es la más cara y su precio es de 8500000 EUR.

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# TODO
# obtenemos el VALOR(precio) mínimo de la columna 'price' mediante la function .min() que nos devuelve el valor mínimo de la columna/ columnas 
# si no especificamos nada.
cheap_house = ds['price'].min()

# obtenemos la POSICIÓN del valor mínimo de la columna 'price'.
position_cheap_house = ds['price'].argmin()

# Accedemos al elemento específico (la dirección de la casa), utilizando la function .loc[row,column] (By Index), en la columna 'address' 
# ya sabiendo la posición(row) del paso anterior.
address_cheap_house= ds.loc[position_cheap_house, 'address']

print(f"La casa con dirección en {address_cheap_house} es la más barata y su precio es de {round(cheap_house, 2)} EUR.")
# Out:
# La casa con dirección en Parla es la más barata y su precio es de 0 EUR.

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
# TODO
# obtenemos la superficie máxima de la columna 'surface' mediante la function .max() que nos devuelve el valor máximo de la columna/ columnas si no especificamos nada.
biggest_house = ds['surface'].max()

# obtenemos la POSICIÓN del valor máximo de la columna 'surface'.
position_biggest_house = ds['surface'].argmax()

# Accedemos al elemento específico (la dirección de la casa), utilizando la function .loc[row,column] (By Index), en la columna 'address' ya sabiendo la posición(row) del paso anterior.
address_biggest_house= ds.loc[position_biggest_house, 'address']

# El mismo procedimiento para la casa más pequeña
smallest_house = ds['surface'].min()

address_smallest_house= ds.loc[ds['surface'].argmin(), 'address']

print(f"La casa más grande está ubicada en {address_biggest_house} y su superficie es de {biggest_house} metros cuadrados")
print(f"La casa más pequeña está ubicada en {address_smallest_house} y su superficie es de {smallest_house} metros cuadrados")
# Out:
# La casa más grande está ubicada en Sevilla la Nueva y su superficie es de 249000.0 metros cuadrados
# La casa más pequeña está ubicada en Calle Amparo,  Madrid Capital y su superficie es de 15.0 metros cuadrados

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO

# Retorno de los valores unicos de la columna 'level5'(poblaciones). SIN ORDENAR  
unique_populations_list = ds['level5'].unique()

# Ordenamos la lista
sorted_populations_list = sorted(unique_populations_list)

# Con la function .nunique() obtenemos el número de elementos unicos que hay en la columna indicada (en este caso 'level5'). 
print(f"\nEn la columna 'level5' hay un total de {ds['level5'].nunique()} poblaciones diferentes.\n")

print(sorted_populations_list)
# Out:
# En la columna 'level5' hay un total de 168 poblaciones diferentes.
#
# [' Madrid Capital', 'Ajalvir', 'Alcalá de Henares', 'Alcobendas', 'Alcorcón', 'Aldea del Fresno', 'Algete', 'Alpedrete', 'Ambite', 'Anchuelo', 'Aranjuez', 'Arganda del Rey', 'Arroyomolinos (Madrid)', 'Batres', 'Becerril de la Sierra', 'Belmonte de Tajo', 'Boadilla del Monte', 'Braojos', 'Brea de Tajo', 'Brunete', 'Buitrago del Lozoya', 'Bustarviejo', 'Cabanillas de la Sierra', 'Cadalso de los Vidrios', 'Camarma de Esteruelas', 'Campo Real', 'Canencia', 'Carabaña', 'Casarrubuelos', 'Cenicientos', 'Cercedilla', 'Chapinería', 'Chinchón', 'Ciempozuelos', 'Cobeña', 'Collado Mediano', 'Collado Villalba', 'Colmenar Viejo', 'Colmenar de Oreja', 'Colmenar del Arroyo', 'Colmenarejo', 'Corpa', 'Coslada', 'Cubas de la Sagra', 'Daganzo de Arriba', 'El Atazar', 'El Berrueco', 'El Boalo - Cerceda – Mataelpino', 'El Escorial', 'El Molar (Madrid)', 'El Vellón', 'El Álamo', 'Estremera', 'Fresnedillas de la Oliva', 'Fresno de Torote', 'Fresno de Torote - Serracines', 'Fuenlabrada', 'Fuente El Saz de Jarama', 'Fuentidueña de Tajo', 'Galapagar', 'Garganta de los Montes', 'Gargantilla del Lozoya', 'Gascones', 'Getafe', 'Griñón', 'Guadalix de la Sierra', 'Guadarrama', 'Horcajo de la Sierra', 'Hoyo de Manzanares', 'Humanes de Madrid', 'La Cabrera', 'La Hiruela', 'Las Rozas de Madrid', 'Leganés', 'Loeches', 'Los Molinos', 'Los Santos de la Humosa', 'Lozoya', 'Lozoyuela-navas-sieteiglesias', 'Madarcos', 'Majadahonda', 'Manzanares El Real', 'Meco', 'Mejorada del Campo', 'Miraflores de la Sierra', 'Montejo de la Sierra', 'Moraleja de Enmedio', 'Moralzarzal', 'Morata de Tajuña', 'Móstoles', 'Navacerrada', 'Navalafuente', 'Navalagamella', 'Navalcarnero', 'Navarredonda', 'Navas del Rey', 'Nuevo Baztán', 'Orusco de Tajuña', 'Paracuellos de Jarama', 'Parla', 'Patones', 'Pedrezuela', 'Pelayos de la Presa', 'Perales de Tajuña', 'Pezuela de las Torres', 'Pinilla del Valle', 'Pinto', 'Piñuécar-gandullas', 'Pozuelo de Alarcón', 'Pozuelo del Rey', 'Puentes Viejas', 'Quijorna', 'Rascafría', 'Redueña', 'Ribatejada', 'Rivas-vaciamadrid', 'Robledo de Chavela', 'Robregordo', 'San Agustín del Guadalix', 'San Fernando de Henares', 'San Lorenzo de El Escorial', 'San Martín de Valdeiglesias', 'San Martín de la Vega', 'San Sebastián de los Reyes', 'Santa María de la Alameda', 'Santorcaz', 'Serranillos del Valle', 'Sevilla la Nueva', 'Soto del Real', 'Talamanca de Jarama', 'Tielmes', 'Titulcia', 'Torrejón de Ardoz', 'Torrejón de Velasco', 'Torrejón de la Calzada', 'Torrelaguna', 'Torrelodones', 'Torremocha de Jarama', 'Torres de la Alameda', 'Tres Cantos', 'Valdaracete', 'Valdeavero', 'Valdelaguna', 'Valdemanco', 'Valdemaqueda', 'Valdemorillo', 'Valdemoro', 'Valdeolmos-Alalpardo', 'Valdepiélagos', 'Valdetorres de Jarama', 'Valdilecha', 'Valverde de Alcalá', 'Velilla de San Antonio', 'Venturada', 'Villa del Prado', 'Villaconejos', 'Villalbilla', 'Villamanrique de Tajo', 'Villamanta', 'Villamantilla', 'Villanueva de Perales', 'Villanueva de la Cañada', 'Villanueva del Pardillo', 'Villar del Olmo', 'Villarejo de Salvanés', 'Villaviciosa de Odón', 'Villavieja del Lozoya', 'Zarzalejo']

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
# TODO

# Detecta valores perdidos. Devuelve un booleano del mismo tamaño que el original indicando si los valores son NA.(None or np.NaN son considerados true values)
ds.isna()
# Out:
#        Unnamed: 0  id_realEstates  isNew  realEstate_name  phone_realEstate  \
# 0           False           False  False            False             False
# 1           False           False  False            False             False
# 2           False           False  False            False             False
# 3           False           False  False            False             False
# 4           False           False  False            False             False
# ...           ...             ...    ...              ...               ...
# 15330       False           False  False            False             False
# 15331       False           False  False            False             False
# 15332       False           False  False            False             False
# 15333       False           False  False            False             False
# 15334       False           False  False            False             False
#
#        url_inmueble  rooms  bathrooms  surface  price  ...  level4Id  \
# 0             False  False      False    False  False  ...     False
# 1             False  False      False     True  False  ...     False
# 2             False  False      False    False  False  ...     False
# 3             False  False      False    False  False  ...     False
# 4             False  False      False    False  False  ...     False
# ...             ...    ...        ...      ...    ...  ...       ...
# 15330         False  False      False    False  False  ...     False
# 15331         False  False      False    False  False  ...     False
# 15332         False  False      False    False  False  ...     False
# 15333         False  False      False    False  False  ...     False
# 15334         False  False      False    False  False  ...     False
#
#        level5Id  level6Id  level7Id  level8Id  accuracy  latitude  longitude  \
# 0         False     False     False     False     False     False      False
# 1         False     False     False     False     False     False      False
# 2         False     False     False     False     False     False      False
# 3         False     False     False     False     False     False      False
# 4         False     False     False     False     False     False      False
# ...         ...       ...       ...       ...       ...       ...        ...
# 15330     False     False     False     False     False     False      False
# 15331     False     False     False     False     False     False      False
# 15332     False     False     False     False     False     False      False
# 15333     False     False     False     False     False     False      False
# 15334     False     False     False     False     False     False      False
#
#        zipCode  customZone
# 0         True        True
# 1         True        True
# 2         True        True
# 3         True        True
# 4         True        True
# ...        ...         ...
# 15330     True        True
# 15331     True        True
# 15332     True        True
# 15333     True        True
# 15334     True        True
#
# [15335 rows x 37 columns]

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
# TODO

ds = pd.read_csv('assets/real_estate.csv', sep=';')

# df.shape devuelve una tupla con el número de filas y columnas del DataFrame.
# Les asignamos nombre a cada valor para obtener el número de filas y columnas por separado.
filas, columnas = ds.shape
print(f"Las dimensiones del DataFrame original son:\n  Filas: {filas}\n  Columnas: {columnas} ")

# df.dropna() remove missing values
# axis = 1, or ‘columns’ : Drop columns which contain missing value.
#‘any’ : If any NA values are present, drop that row or column.
ds.dropna(axis=1, how='any', inplace=True)

# df.shape devuelve una tupla con el número de filas y columnas del DataFrame.
# Les asignamos nombre a cada valor para obtener el número de filas y columnas por separado.
filas, columnas = ds.shape

print(f"Las dimensiones del DataFrame después de eliminar los NAs son:\n  Filas: {filas}\n  Columnas: {columnas} ")
print("Conclusión: Han habido doce columnas que contenian en ellas al menos un valor NAs.")
# Out:
# Las dimensiones del DataFrame original son:
#   Filas: 15335
#   Columnas: 37
# Las dimensiones del DataFrame después de eliminar los NAs son:
#   Filas: 15335
#   Columnas: 25
# Conclusión: Han habido doce columnas que contenian en ellas al menos un valor NAs.

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
# TODO

#Selecciono las filas donde el nombre sea igual a 'Arroyomolinos (Madrid').
num_poblacion_arroyomolinos = ds[ds['level5']=="Arroyomolinos (Madrid)"]

#las media de los precios de las casas que estan en 'Arroyomolinos (Madrid)
mean_price = num_poblacion_arroyomolinos['price'].mean()


print(f"La media de precios en Arroyomolinos (Madrid) es de: {round(mean_price,2)} EUR")
# Out:
# La media de precios en Arroyomolinos (Madrid) es de: 294541.6 EUR

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
# TODO: Code
import pandas as pd
import matplotlib.pyplot as plt

#Selecciono las filas donde el nombre sea igual a 'Arroyomolinos (Madrid').
num_poblacion_arroyomolinos = ds[ds['level5']=="Arroyomolinos (Madrid)"]

#Histograma 
plt.hist(num_poblacion_arroyomolinos['price'], bins=40,
          edgecolor = 'black',
          color = 'darkblue',
          alpha = 0.7)

#Añadir Título y etiquetas
plt.title("Precios para la población de Arroyomolinos (Madrid)")
plt.xlabel('Precios (EUR)')
plt.ylabel('Frecuencia')

#Añadir cuadrícula
plt.grid(True)

#Añadir una anotación
plt.text(300000,16.5,'<-Frecuencia máx',fontsize=12, color='red')

#Mostrar gráfico
plt.show()

# Statistic summary para un breve análisis del trazado
num_poblacion_arroyomolinos['price'].describe()
# Out:
# count       137.00000
# mean     294541.59854
# std       84183.51590
# min           0.00000
# 25%      229900.00000
# 50%      289000.00000
# 75%      348900.00000
# max      580000.00000
# Name: price, dtype: float64

# %% [markdown]
# **TODO: Markdown**. Podemos observar una pequeña asimetría hacia la derecha. Esto lo podemos saber porque el valor de la media: 294541.6 es mayor que el de la mediana: 289000.0.
# También vemos un intervalo de valores atípicos en el 0. Como conclusión podemos decir que la mayoría de precios se encuentran entre 200000 EUR y 400000 EUR y los sesgos no influyen notablemente en la media de los precios, por lo que, la mayoría de las casas están en un rango de precio moderado.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
# TODO

#subconjunto que cumpla que sea igual a valdemorillo
num_poblacion_valdemorillo = ds[ds['level5']=="Valdemorillo"]

#subconjunto que cumpla que sea igual a Galapagar
num_poblacion_galapagar = ds[ds['level5']=="Galapagar"]

#las media de los precios de las casas que estan en 'Valdemorillo'
mean_price_valdemorillo = num_poblacion_valdemorillo['price'].mean()
#las media de los precios de las casas que estan en 'Galapagar'
mean_price_galapagar = num_poblacion_galapagar['price'].mean()

print(f"El valor medio de las propiedades en Valdemorillo es de: {round(mean_price_valdemorillo, 2)}EUR.\n"
      f"El valor medio de las propiedades en Galapagar es de: {round(mean_price_galapagar, 2)} EUR.")

print("El promedio de precios que hay en la población: Valdemorillo y en la población: Galapagar es que casi idéntica. Los precios son muy parecidos.")
# Out:
# El valor medio de las propiedades en Valdemorillo es de: 363860.29EUR.
# El valor medio de las propiedades en Galapagar es de: 360063.2 EUR.
# El promedio de precios que hay en la población: Valdemorillo y en la población: Galapagar es que casi idéntica. Los precios son muy parecidos.

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# TODO

ds = pd.read_csv('assets/real_estate.csv', sep=';')

data = ds[ds['level5'].isin(['Valdemorillo','Galapagar'])]

# Creamos una columna llamada pps (price per square). Los datos son price/surface
ds['pps'] = data['price'] / data['surface']

avg_price_valdemorillo = ds[ds['level5']=='Valdemorillo']['pps'].mean()
avg_price_galapagar = ds[ds['level5']=='Galapagar']['pps'].mean()

print(f"El promedio del precio por metro cuadrado en Valdemorillo es de : {round(avg_price_valdemorillo, 2)} EUR/m^2\n"
      f"El promedio del precio por metro cuadrado en Galapagar es de: {round(avg_price_galapagar, 2)} EUR/m^2.")

diferencia_absoluta = avg_price_galapagar - avg_price_valdemorillo
diferencia_relativa = ((avg_price_galapagar - avg_price_valdemorillo) / avg_price_valdemorillo) * 100

print(f"Esto representa una diferencia absoluta de {round(diferencia_absoluta,2)} EUR por metro cuadrado.\n"
      f"Relativamente, el precio en Galapagar es aproximadamente un {round(diferencia_relativa,2)}% más alto que en Valdemorillo.")
# Out:
# El promedio del precio por metro cuadrado en Valdemorillo es de : 1317.95 EUR/m^2
# El promedio del precio por metro cuadrado en Galapagar es de: 1606.32 EUR/m^2.
# Esto representa una diferencia absoluta de 288.37 EUR por metro cuadrado.
# Relativamente, el precio en Galapagar es aproximadamente un 21.88% más alto que en Valdemorillo.

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
# TODO: Código
import pandas as pd
import matplotlib.pyplot as plt

ds = pd.read_csv('assets/real_estate.csv', sep=';')


plt.figure(figsize=(10,6))
plt.scatter(ds['price'], ds['surface'], color='blue', alpha=0.7, edgecolors='w')
plt.xlabel('Surface')
plt.ylabel('Price')
plt.title('scatter plot')
plt.grid(True)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# TODO

ds = pd.read_csv('assets/real_estate.csv', sep=';')

# Obtenemos el número único de agencias de bienes raíces que hay en la columna 'realEstate_name'
num_agencia_bienes_raices = ds['realEstate_name'].nunique()

print(f"El número de agencias diferentes es de: {num_agencia_bienes_raices} agencias")
# Out:
# El número de agencias diferentes es de: 1821 agencias

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# TODO
# Con .value_counts obtenemos el número de veces que se repite cada elemento de la columna 'level5'.
numero_casas = ds['level5'].value_counts()


# Devuelve el index con mas frecuencia sobre el axis propuesto.
poblacion = numero_casas.idxmax()


# Nos devuelve el valor máximo
mas_numero_casas = numero_casas.max()

print(f"La población que contiene el mayor número de casas es {poblacion} con un total de: {mas_numero_casas} casas.")
# Out:
# La población que contiene el mayor número de casas es  Madrid Capital con un total de: 6643 casas.

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
# TODO
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')

cinturon_sur = ds[ds['level5'].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]
cinturon_sur.head()
# Out:
#      Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 1             2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 3             4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 85           86       153152077  False            sinergical inmobiliaria
# 94           95       153995577  False                    viviendas365com
# 109         110       153586414  False    area uno asesores inmobiliarios
#
#      phone_realEstate                                       url_inmueble  \
# 1         916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3         916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 85                NaN  https://www.fotocasa.es/es/comprar/vivienda/le...
# 94        911226014.0  https://www.fotocasa.es/es/comprar/vivienda/le...
# 109       912664081.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#      rooms  bathrooms  surface   price  ... level4Id level5Id level6Id  \
# 1      3.0        1.0      NaN   89000  ...        0        0        0
# 3      3.0        1.0     86.0   89000  ...        0        0        0
# 85     1.0        1.0     50.0  107000  ...        0        0        0
# 94     3.0        2.0    120.0  320000  ...        0        0        0
# 109    3.0        3.0    142.0  425000  ...        0        0        0
#
#     level7Id level8Id accuracy          latitude          longitude zipCode  \
# 1          0        0        1          40,28674           -3,79351     NaN
# 3          0        0        0  40,2853785786438  -3,79508142135624     NaN
# 85         0        0        1          40,35059           -3,82693     NaN
# 94         0        0        0          40,31933           -3,77574     NaN
# 109        0        0        0        40,3313411         -3,8313868     NaN
#
#     customZone
# 1          NaN
# 3          NaN
# 85         NaN
# 94         NaN
# 109        NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
# TODO: Code

import matplotlib.pyplot as plt

cinturon_sur = ds[ds['level5'].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]

median_price = cinturon_sur.groupby('level5')['price'].median()

# Gráfico de barras 
plt.bar( x = median_price.index, height = median_price.values,
        edgecolor = 'black',
        color = 'darkblue',
        alpha = 0.9)

# Título y labels
plt.title('Mediana de los precios')
plt.xlabel('Población')
plt.ylabel('Precio')

# Textos en las barras
plt.text(-0.35,165000,median_price.loc["Alcorcón"],fontsize=12, color='w')
plt.text(0.65,140000,median_price.loc["Fuenlabrada"],fontsize=12, color='w')
plt.text(1.65,270000,median_price.loc["Getafe"],fontsize=12, color='w')
plt.text(2.65,155000,median_price.loc["Leganés"],fontsize=12, color='w')

plt.show()

# %% [markdown]
# **TODO: Markdown**. Los precios de Getafe son notablemente más caros que los del resto de poblaciones. En cuanto al resto observamos que los precios de Fuenlabrada son los más baratos, después les sigue Leganés y como segundos más caros los de Alcorcón.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# TODO

cinturon_sur = ds[ds['level5'].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]

# Calculamos la media de las variables 'price', 'rooms', 'surface', 'bathrooms'.
mean_price = cinturon_sur['price'].mean()
mean_rooms = cinturon_sur['rooms'].mean()
mean_surface = cinturon_sur['surface'].mean()
mean_bathrooms = cinturon_sur['bathrooms'].mean()

# Calculamos la varianza de las variables 'price', 'rooms', 'surface', 'bathrooms'.
variance_price = cinturon_sur['price'].var()
variance_rooms = cinturon_sur['rooms'].var()
variance_surface = cinturon_sur['surface'].var()
variance_bathrooms = cinturon_sur['bathrooms'].var()

print(f"Para la variable 'Precio' la media es: {round(mean_price,2)} y la varianza: {round(variance_price,2)}")
print(f"Para la variable 'Habitaciones' la media es: {round(mean_rooms,2)} y la varianza: {round(variance_rooms,2)}")
print(f"Para la variable 'Superficie' la media es: {round(mean_surface,2)} y la varianza: {round(variance_surface,2)}")
print(f"Para la variable 'Baños' la media es: {round(mean_bathrooms,2)} y la varianza: {round(variance_bathrooms,2)}")
# Out:
# Para la variable 'Precio' la media es: 223094.48 y la varianza: 14921367508.05
# Para la variable 'Habitaciones' la media es: 3.02 y la varianza: 0.72
# Para la variable 'Superficie' la media es: 111.75 y la varianza: 4263.05
# Para la variable 'Baños' la media es: 1.63 y la varianza: 0.57

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# TODO

cinturon_sur = ds[ds['level5'].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]

# POBLACIÓN: FUENLABRADA......................................

# Filtrar y obtener el Índice del valor máximo que hay en la columna 'price' para las filas donde 'level5' es 'Fuenlabrada'
address_fuenlabrada_id = cinturon_sur.loc[cinturon_sur['level5'] == 'Fuenlabrada', 'price'].idxmax()
# Filtrar y obtener el valor máximo de 'price' para las filas donde 'level5' es 'Fuenlabrada'
price_max_fuenlabrada = cinturon_sur.loc[cinturon_sur['level5'] == 'Fuenlabrada', 'price'].max()
# Filtrar y obtener el la dirección usando .loc[] en la columna address
address_fuenlabrada = cinturon_sur.loc[address_fuenlabrada_id, 'address'] 


# POBLACIÓN: LEGANÉS..........................................

# Filtrar y obtener el Índice del valor máximo que hay en la columna 'price' para las filas donde 'level5' es 'Leganés'
address_leganes_id = cinturon_sur.loc[cinturon_sur['level5'] == 'Leganés', 'price'].idxmax()
# Filtrar y obtener el valor máximo de 'price' para las filas donde 'level5' es 'Leganés'
price_max_leganes = cinturon_sur.loc[cinturon_sur['level5'] == 'Leganés', 'price'].max()
# Filtrar y obtener el la dirección usando .loc[] en la columna address
address_leganes = cinturon_sur.loc[address_leganes_id, 'address']


# POBLACIÓN: GETAFE...........................................

# Filtrar y obtener el Índice del valor máximo que hay en la columna 'price' para las filas donde 'level5' es 'Getafe'
address_getafe_id = cinturon_sur.loc[cinturon_sur['level5'] == 'Getafe', 'price'].idxmax()
# Filtrar y obtener el valor máximo de 'price' para las filas donde 'level5' es 'Getafe'
price_max_getafe = cinturon_sur.loc[cinturon_sur['level5'] == 'Getafe', 'price'].max()
# Filtrar y obtener el la dirección usando .loc[] en la columna address
address_getafe = cinturon_sur.loc[address_getafe_id, 'address']


# POBLACIÓN: ALCORCÓN.........................................

# Filtrar y obtener el Índice del valor máximo que hay en la columna 'price' para las filas donde 'level5' es 'Alcorcón'
address_alcorcon_id = cinturon_sur.loc[cinturon_sur['level5'] == 'Alcorcón', 'price'].idxmax() #INDICE MAX VALOR   
# Filtrar y obtener el valor máximo de 'price' para las filas donde 'level5' es 'Alcorcón'
price_max_alcorcon = cinturon_sur.loc[cinturon_sur['level5'] == 'Alcorcón', 'price'].max()
# Filtrar y obtener el la dirección usando .loc[] en la columna address
address_alcorcon = cinturon_sur.loc[address_alcorcon_id, 'address']


print(f"\nLa casa más cara de la población Fuenlabrada tiene un precio de {price_max_fuenlabrada} EUR con dirección en {address_fuenlabrada}.\n")
print(f"La casa más cara de la población Leganés tiene un precio de {price_max_leganes} EUR con dirección en {address_leganes}.\n")
print(f"La casa más cara de la población Getafe tiene un precio de {price_max_getafe} EUR con dirección en {address_getafe}.\n")
print(f"La casa más cara de la población Alcorcón tiene un precio de {price_max_alcorcon} EUR con dirección en {address_alcorcon}.\n")
# Out:
# La casa más cara de la población Fuenlabrada tiene un precio de 490000 EUR con dirección en Calle de Paulo Freire, 5, Fuenlabrada.
#
# La casa más cara de la población Leganés tiene un precio de 650000 EUR con dirección en Avenida Reina Sofía, Leganés.
#
# La casa más cara de la población Getafe tiene un precio de 1050000 EUR con dirección en Getafe.
#
# La casa más cara de la población Alcorcón tiene un precio de 950000 EUR con dirección en Alcorcón.

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
# TODO   #FALTA LAS CONCLUSIONES Y EXPLICACIÓN DE NORMALIZACIÓN

import pandas as pd
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None  # default='warn'
cinturon_sur = ds[ds['level5'].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]


# NUEVA COLUMNA CON LOS PRECIOS NORMALIZADOS
cinturon_sur['Normalización'] = (cinturon_sur['price'] - cinturon_sur['price'].mean()) / cinturon_sur['price'].std()

# valores normalizados de cada población
normalizacion_fuenlabrada = cinturon_sur.loc[cinturon_sur['level5'] == 'Fuenlabrada', 'Normalización']

normalizacion_leganes = cinturon_sur.loc[cinturon_sur['level5'] == 'Leganés', 'Normalización']

normalizacion_getafe = cinturon_sur.loc[cinturon_sur['level5'] == 'Getafe', 'Normalización']

normalizacion_alcorcon = cinturon_sur.loc[cinturon_sur['level5'] == 'Alcorcón', 'Normalización']

# Crear la figura y los subplots
fig, axis = plt.subplots(2, 2, figsize=(10, 8))

# Histograma Fuenlabrada
axis[0, 0].hist(normalizacion_fuenlabrada, bins=30, color='blue', edgecolor='black')
axis[0, 0].set_title('Fuenlabrada')

# Histograma Leganés
axis[0, 1].hist(normalizacion_leganes, bins=30, color='green', edgecolor='black')
axis[0, 1].set_title('Leganés')

# Histograma Getafe
axis[1, 0].hist(normalizacion_getafe, bins=30, color='red', edgecolor='black')
axis[1, 0].set_title('Getafe')

# Histograma Alcorcón
axis[1, 1].hist(normalizacion_alcorcon, bins=30, color='purple', edgecolor='black')
axis[1, 1].set_title('Alcorcón')

# Ajustar el diseño
plt.tight_layout()


plt.show()

# %% [markdown]
# **TODO: Markdown**. En textos de estadística frecuentemente se habla de variable normalizada, también se conoce como unidad tipificada, variable centrada reducida o variable estandarizada. Normalizar una variable es simplemente expresar su magnitud en unidades de desviación estándar.
# Es importante entender que normalizar una variable no cambia su valor, solo su unidad de cuenta.
# Normalizar las variables nos permite comparar su distribución independientemente de su unidad de cuenta y amplitud, también nos permite sacar conclusiones sobre probabilidades y proporciones.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
# TODO
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

# Subconjunto obtenido en la pregunta 14.
cinturon_sur = ds[ds['level5'].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]

# Creamos una columna en el subplot cinturon_sur llamada pps (price per square). Los datos son price/surface
cinturon_sur['pps'] = cinturon_sur['price'] / cinturon_sur['surface']

# Precio por metro cuadrado de Getafe
pps_getafe = cinturon_sur[cinturon_sur['level5']=='Getafe']['pps'].mean()

# Precio por metro cuadrado de Alcorcón
pps_alcorcon = cinturon_sur[cinturon_sur['level5']=='Alcorcón']['pps'].mean()


poblaciones = ['Getafe', 'Alcorcón']
precios = [pps_getafe, pps_alcorcon]

plt.bar(poblaciones, precios, color=['blue', 'green'])
plt.ylabel('Precio Medio por m²')
plt.title('Comparación del Precio Medio por Metro Cuadrado')
plt.show()

diferencia_absoluta = pps_alcorcon - pps_getafe
diferencia_relativa = ((pps_alcorcon - pps_getafe) / pps_getafe) * 100

print(f"El precio medio del metro cuadrado en Getafe es de {round(pps_getafe,2)} EUR, mientras que en Alcorcón es de {round(pps_alcorcon,2)} EUR.\n"
      f"Esto representa una diferencia absoluta de {round(diferencia_absoluta,2)} EUR por metro cuadrado.\n"
      f"Relativamente, el precio en Alcorcón es aproximadamente un {round(diferencia_relativa,2)}% más alto que en Getafe.")
# Out:
# El precio medio del metro cuadrado en Getafe es de 2066.31 EUR, mientras que en Alcorcón es de 2239.3 EUR.
# Esto representa una diferencia absoluta de 172.99 EUR por metro cuadrado.
# Relativamente, el precio en Alcorcón es aproximadamente un 8.37% más alto que en Getafe.

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
# TODO
import matplotlib.pyplot as plt

# Subconjunto obtenido en la pregunta 14.
cinturon_sur = ds[ds['level5'].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]


x1 = cinturon_sur.loc[cinturon_sur['level5'] == 'Fuenlabrada', 'surface']
y1 = cinturon_sur.loc[cinturon_sur['level5'] == 'Fuenlabrada', 'price']

x2 = cinturon_sur.loc[cinturon_sur['level5'] == 'Leganés', 'surface']
y2 = cinturon_sur.loc[cinturon_sur['level5'] == 'Leganés', 'price']

x3 = cinturon_sur.loc[cinturon_sur['level5'] == 'Getafe', 'surface']
y3 = cinturon_sur.loc[cinturon_sur['level5'] == 'Getafe', 'price']

x4 = cinturon_sur.loc[cinturon_sur['level5'] == 'Alcorcón', 'surface']
y4 = cinturon_sur.loc[cinturon_sur['level5'] == 'Alcorcón', 'price']



# Crear una figura y un solo conjunto de ejes
fig, axis = plt.subplots(figsize=(12, 6))

# Graficar el primer conjunto de datos
axis.scatter(x1, y1, color='r', label='Price per square Fuenlabrada')
axis.scatter(x2, y2, color='b', label='Price per square Leganés')
axis.scatter(x3, y3, color='g', label='Price per square Getafe')
axis.scatter(x4, y4, color='c', label='Price per square Alcorcón')


# Añadir leyenda
axis.legend()

# Ajustar el diseño
plt.tight_layout()

# Añadir título y etiquetas
axis.set_title('Diagrama de Dispersión con Múltiples Conjuntos de Datos')
axis.set_xlabel('Metros cuadrados')
axis.set_ylabel('Precios')
# Out:
# Text(112.72222222222221, 0.5, 'Precios')

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en (60 grados latitud y -2.2 grados longitud)
# Latitud, longitud
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/xyzservices/lib.py:45, in Bunch.__getattr__(self, key)
#      44 try:
# ---> 45     return self.__getitem__(key)
#      46 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 6
#       1 from ipyleaflet import Map, basemaps
#       3 # Mapa centrado en (60 grados latitud y -2.2 grados longitud)
#       4 # Latitud, longitud
#       5 map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20,
# ----> 6     basemap=basemaps.Stamen.Terrain)
#       7 map
#
# File ~/.local/lib/python3.11/site-packages/xyzservices/lib.py:47, in Bunch.__getattr__(self, key)
#      45     return self.__getitem__(key)
#      46 except KeyError as err:
# ---> 47     raise AttributeError(key) from err
#
# AttributeError: Stamen

# %%
from ipyleaflet import Map, basemaps
import matplotlib.pyplot as plt
from ipyleaflet import Map, Marker, MarkerCluster, basemaps

## Aquí: traza la coordenadas de los estados

## PON TU CÓDIGO AQUÍ:
cinturon_sur = ds[ds['level5'].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]
